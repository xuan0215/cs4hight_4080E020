# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew267/cs4hight_4080E020/blob/master/%E2%80%9CPython_1_IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 輸入與輸出(Input and Output)2019.09.19
#
# 單元學習目標:
#
# python輸入:input(), raw_input()
#
# python輸出: print()
#
# python格式化輸出技術 老師教的 很重要:必考考考

# %% [markdown]
# ## 基本輸入:讀取使用者的輸入
# ```
# 使用input時，會從標準輸入(stdin)中讀取輸入資料
# 這些資料是string字串型態{重要}
# ```
#
# stdin==Standard Input

# %%
x = input('請輸入你的名子:')
print('看三小啦, ' + x)
# Out:
# 請輸入你的名子:安德烈
# 看三小啦, 安德烈

# %%
a = input("請輸入：")
a
# Out:
# 請輸入：200
# '200'

# %% [markdown]
# ###  Python內建的type()函數可以顯示資料型態
# str=字串資料型態

# %%
type(a)
# Out:
# str

# %% [markdown]
# ### 錯誤的做法：請指出底下程式的錯誤
# type error
# type=資料型態=data type

# %%
a = input("請輸入：")
a
b=a+1
b
# Out:
# 請輸入：99
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c41d06678cb4> in <module>()
#       1 a = input("請輸入：")
#       2 a
# ----> 3 b=a+1
#       4 b
#
# TypeError: must be str, not int

# %% [markdown]
# ## 基本輸入:讀取使用者輸入的整數
#
# 使用eval()函數

# %%
c = int(input("請輸入:"))
type (c)
# Out:
# 請輸入:200
# int

# %%
a = eval(input("請輸入："))
a
# Out:
# 請輸入：100
# 100

# %%
b=c+1
b
# Out:
# 201

# %% [markdown]
# ## 超級重要:可以一次輸入多（兩）個資料

# %%
a,b = eval(input("請輸入兩個數位："))
a,b
# Out:
# 請輸入兩個數位：12,23
# (12, 23)

# %% [markdown]
# 要加逗號分開

# %% [markdown]
# ### 高階技巧:

# %%
x, y, z = [int(x) for x in input("Enter three value: ").split()] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print("Third Number is: ", z) 
print()
# Out:
# Enter three value: 2 3 4
# First Number is:  2
# Second Number is:  3
# Third Number is:  4

# %%
x, y, z = [int(x) for x in input("Enter three value: ").split(",")] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print("Third Number is: ", z) 
print()

# %%
a, b = input("Enter a two value: ").split() 
print("First number is {} and second number is {}".format(a, b)) 
print()
# Out:
# Enter a two value: 1 2
# First number is 1 and second number is 2

# %%
# Out:
# '0xff'
